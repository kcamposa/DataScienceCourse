# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dir_datasets = '/content/drive/MyDrive/DataScience/Data Science Course/0.Datasets/{}'
df_cars = pd.read_csv(dir_datasets.format('Car_sales.csv'), encoding='latin-1')

# %%
df_cars = df_cars[['Manufacturer', 'Sales_in_thousands', 'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Fuel_capacity']]
df_cars
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %% [markdown]
# # **GROUPBY() AND AGG()**

# %%
df_cars.columns
# Out:
# Index(['Manufacturer', 'Sales_in_thousands', 'Vehicle_type',
#        'Price_in_thousands', 'Engine_size', 'Horsepower', 'Fuel_capacity'],
#       dtype='object')

# %%
df_cars.groupby('Vehicle_type').agg(['min', 'max'])
# Out:
#              Manufacturer         Sales_in_thousands           \
#                       min     max                min      max
# Vehicle_type
# Car              Cadillac  Toyota              9.126  540.561
# Passenger           Acura   Volvo              0.110  247.994
#
#              Price_in_thousands         Engine_size      Horsepower         \
#                             min     max         min  max        min    max
# Vehicle_type
# Car                      11.528  60.105         2.0  5.7      119.0  300.0
# Passenger                 9.235  85.500         1.0  8.0       55.0  450.0
#
#              Fuel_capacity
#                        min   max
# Vehicle_type
# Car                   15.1  32.0
# Passenger             10.3  23.7

# %%
df_cars.groupby('Vehicle_type', as_index=False).agg(min_engine_size=('Engine_size', 'min'),
                                                    max_engine_size=('Engine_size', 'max'),
                                                    min_horsepower=('Horsepower', 'min'),
                                                    max_horsepower=('Horsepower','max'))
# Out:
#   Vehicle_type  min_engine_size  max_engine_size  min_horsepower  \
# 0          Car              2.0              5.7           119.0
# 1    Passenger              1.0              8.0            55.0
#
#    max_horsepower
# 0           300.0
# 1           450.0

# %%
df_cars.groupby('Manufacturer').agg(sum_sales =('Sales_in_thousands', 'sum'),
                                    average_price=('Price_in_thousands','mean')).head()
# Out:
#               sum_sales  average_price
# Manufacturer
# Acura            79.005      30.633333
# Audi             40.557      39.980000
# BMW              46.505      33.096667
# Buick           242.019      26.781250
# Cadillac        112.178      40.254000

# %%
df_cars.groupby('Manufacturer').sum()['Sales_in_thousands'].head()
# Out:
# Manufacturer
# Acura        79.005
# Audi         40.557
# BMW          46.505
# Buick       242.019
# Cadillac    112.178
# Name: Sales_in_thousands, dtype: float64

# %%
df_cars.groupby('Manufacturer').mean()['Price_in_thousands'].head()
# Out:
# Manufacturer
# Acura       30.633333
# Audi        39.980000
# BMW         33.096667
# Buick       26.781250
# Cadillac    40.254000
# Name: Price_in_thousands, dtype: float64
