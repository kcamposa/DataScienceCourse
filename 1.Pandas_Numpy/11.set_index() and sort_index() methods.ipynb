# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dir_datasets = '/content/drive/MyDrive/DataScience/Data Science Course/0.Datasets/{}'
df_exams = pd.read_csv(dir_datasets.format('StudentsPerformance.csv'), sep=',')

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# create values no repetitives for the index
new_index = np.arange(0, 1000)

# %%
# scrumble the indexs
np.random.shuffle(new_index)
new_index

# %%
# create a new colums with de new index
df_exams['new_index'] = new_index
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 236        female        group B           bachelor's degree      standard
# 107        female        group C                some college      standard
# 940        female        group B             master's degree      standard
# 998          male        group A          associate's degree  free/reduced
# 767          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 584        female        group E             master's degree      standard
# 499          male        group C                 high school  free/reduced
# 764        female        group C                 high school  free/reduced
# 14         female        group D                some college      standard
# 696        female        group D                some college  free/reduced
#
# ...

# %%
# set the new index
df_exams.set_index('new_index', inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 236        female        group B           bachelor's degree      standard
# 107        female        group C                some college      standard
# 940        female        group B             master's degree      standard
# 998          male        group A          associate's degree  free/reduced
# 767          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 584        female        group E             master's degree      standard
# 499          male        group C                 high school  free/reduced
# 764        female        group C                 high school  free/reduced
# 14         female        group D                some college      standard
# 696        female        group D                some college  free/reduced
#
# ...

# %%
# order dataframe by new_index
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group C            some high school  free/reduced
# 1            male        group B                some college  free/reduced
# 2          female        group C                some college      standard
# 3          female        group E             master's degree      standard
# 4            male        group B           bachelor's degree      standard
# ...           ...            ...                         ...           ...
# 995          male        group E          associate's degree      standard
# 996        female        group B           bachelor's degree      standard
# 997        female        group C           bachelor's degree  free/reduced
# 998          male        group A          associate's degree  free/reduced
# 999          male        group B           bachelor's degree      standard
#
# ...

# %%
# order desc dataframe by index
df_exams.sort_index(ascending=False, inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group B           bachelor's degree      standard
# 998          male        group A          associate's degree  free/reduced
# 997        female        group C           bachelor's degree  free/reduced
# 996        female        group B           bachelor's degree      standard
# 995          male        group E          associate's degree      standard
# ...           ...            ...                         ...           ...
# 4            male        group B           bachelor's degree      standard
# 3          female        group E             master's degree      standard
# 2          female        group C                some college      standard
# 1            male        group B                some college  free/reduced
# 0          female        group C            some high school  free/reduced
#
# ...
