# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dir_datasets = '/content/drive/MyDrive/DataScience/Data Science Course/0.Datasets/{}'
df_exams = pd.read_csv(dir_datasets.format('StudentsPerformance.csv'), sep=',')

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# **¿Cuando podemos usar assign()?**
#
#
#
# *   Agregar multiples columnas en una sola linea de código
# *   Cuando se necesita sobreescribir los valores de una columna existente (buena práctica)

# %%
# create random numbers for the new columns 
score1 = np.random.randint(1, 100, 1000)
score2 = np.random.randint(1, 100, 1000)

# %%
# create a serie using random numbers
serie1 = pd.Series(score1, index=np.arange(0, 1000))
serie2 = pd.Series(score2, index=np.arange(0, 1000))

# %% [markdown]
# **ASSIGN()**

# %%
# use assign() to add multiple columns
df_exams.assign(score1=serie1, score2=serie2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# ...

# %%
df_movies = df_movies.assign( minutes=df_movies['duration'].str.split(expand=True)[0].astype(int) )

# %% [markdown]
# **INSERT()**

# %%
# use insert() to add a column in a specific position, insert methods doesnt return a copy
df_exams.insert(1, 'test', serie1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    59        group B           bachelor's degree      standard
# 1    female    62        group C                some college      standard
# 2    female    83        group B             master's degree      standard
# 3      male    28        group A          associate's degree  free/reduced
# 4      male    37        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    70        group E             master's degree      standard
# 996    male    81        group C                 high school  free/reduced
# 997  female    54        group C                 high school  free/reduced
# 998  female    68        group D                some college      standard
# 999  female    95        group D                some college  free/reduced
#
# ...
