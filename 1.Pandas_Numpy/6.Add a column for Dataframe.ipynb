# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dir_datasets = '/content/drive/MyDrive/DataScience/Data Science Course/0.Datasets/{}'
df_exams = pd.read_csv(dir_datasets.format('StudentsPerformance.csv'), sep=',')

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# add a value in a column
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create an array of 1000 elements
language_score = np.random.randint(1, 100, size=1000)

# %%
# array size
len(language_score)
# Out:
# 1000

# %%
# add the new array for a new column
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create random decimal numbers between 1 and 100
np.random.uniform(1, 100, 1000)
# Out:
# array([40.16010819,  9.95658016,  4.35567034, 53.90341396, 93.44629806,
#        72.9409759 , 48.65490423, 58.82164984, 83.56213427, 50.69653543,
#        36.39924524, 95.24737565, 16.82243912, 36.52410972, 30.3232489 ,
#        82.48019171, 23.17752037, 48.32481526, 50.15877608,  5.84087112,
#        70.67806367, 46.61119553, 65.0342199 ,  6.68703839, 40.85278165,
#        84.82258016, 16.43579402, 51.49062772, 59.8648921 , 70.02589506,
#        40.04691207, 16.94965249, 28.25685476, 13.77719425, 40.79192554,
#        46.20760135, 94.02637368, 54.637842  , 77.44652324, 63.25409299,
#        51.43928583, 29.84481274, 85.96560929, 56.0086101 , 27.99507367,
#        14.50724609, 36.01933649, 89.74192878, 50.50320818, 20.716495  ,
#        99.86018541, 28.4462534 , 52.62888415, 50.80845947,  4.67087998,
#        36.39765288, 40.03995129, 86.00271351, 38.91443599,  1.48995475,
#        95.5906905 , 24.98400346, 64.99552788, 91.81451378, 79.51804731,
# ...
