# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dir_datasets = '/content/drive/MyDrive/DataScience/Data Science Course/0.Datasets/{}'
df_exams = pd.read_csv(dir_datasets.format('StudentsPerformance.csv'), sep=',')

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# **RENAME COLUMNS**

# %%
# rename column name and overwrite the dataframe 
df_exams = df_exams.rename(columns={'gender':'Gender'})

# %%
# rename column name and overwrite the dataframe using inplace
df_exams.rename(columns={'math score':'MS', 
                         'reading score':'RS',
                         'writing score':'WS'}, 
                inplace=True)
df_exams.head()
# Out:
#    Gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  MS  RS  WS
# 0                    none  72  72  74
# 1               completed  69  90  88
# 2                    none  90  95  93
# 3                    none  47  57  44
# 4                    none  76  78  75

# %% [markdown]
# **RENAME INDEX**

# %%
# rename index 0, 2 and update the dataframe
df_exams.rename(index={0: 'A',
                       1: 'B',
                       2: 'C'}, 
                inplace=True)

df_exams.head()
# Out:
#    Gender race/ethnicity parental level of education         lunch  \
# A  female        group B           bachelor's degree      standard
# B  female        group C                some college      standard
# C  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  MS  RS  WS
# A                    none  72  72  74
# B               completed  69  90  88
# C                    none  90  95  93
# 3                    none  47  57  44
# 4                    none  76  78  75
