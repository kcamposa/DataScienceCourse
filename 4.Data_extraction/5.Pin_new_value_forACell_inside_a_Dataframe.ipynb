# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dir_datasets = '/content/drive/MyDrive/DataScience/Data Science Course/0.Datasets/{}'
df_players = pd.read_csv(dir_datasets.format('players_20.csv'), sep=',')

# %%
df_players = df_players[['short_name', 'long_name',	'age',	'dob',	'height_cm',	'weight_kg',	'nationality',	'club']]

# %%
df_players.set_index('short_name', inplace=True)

# %%
df_players.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %% [markdown]
# # **SET VALUE INTO A CELL**

# %%
# update L. Messi's height_cm
df_players.loc['L. Messi', 'height_cm'] = 175

# %%
df_players.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        175
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %% [markdown]
# # **SET VALUE FOR ALL COLUMN**

# %%
# pin 90 of height_cm for all players

# %%
df_players.loc[:, 'height_cm'] = 190

# %%
df_players
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# # **SET VALUE FOR ALL ROW**

# %%
# get all columns corresponding to last ranked player
df_players.iloc[-1, :]
# Out:
# long_name                         潘喜明
# age                                26
# dob                        1993-01-11
# height_cm                         190
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
# set invalid value for all columns corresponding to ranked players
df_players.iloc[-1, :] = np.nan

# %%
df_players.iloc[-1, :]
# Out:
# long_name      NaN
# age            NaN
# dob            NaN
# height_cm      NaN
# weight_kg      NaN
# nationality    NaN
# club           NaN
# Name: Pan Ximing, dtype: object

# %% [markdown]
# # **SET VALUE FOR MULTIPLE COLUMNS**

# %%
df_players.loc[['L. Messi', 'Cristiano Ronaldo'], ['height_cm']] = 175

# %%
df_players.head(3)
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi               175.0       72.0   Argentina         FC Barcelona
# Cristiano Ronaldo      175.0       83.0    Portugal             Juventus
# Neymar Jr              190.0       68.0      Brazil  Paris Saint-Germain

# %% [markdown]
# # **SET VALUE FOR ROWS WITH CONDITIONS**

# %%
columns = ['age', 'dob', 'height_cm', 'weight_kg']

df_players.loc[df_players['height_cm']>180, columns] = 0
df_players
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   0.0           0
# J. Oblak                                     Jan Oblak   0.0           0
# E. Hazard                                  Eden Hazard   0.0           0
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅   0.0           0
# Xiao Mingjie                              Mingjie Xiao   0.0           0
# Zhang Wei                                           张威   0.0           0
# Wang Haijian                                       汪海健   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...
